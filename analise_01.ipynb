# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/analise_01.xlsx')

# %%
display(df.head())

# %%
df.describe()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2645 entries, 0 to 2644
# Data columns (total 47 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   IDADE                           2617 non-null   float64
#  1   FAIXA_ETARIA                    2645 non-null   object
#  2   GENERO                          2645 non-null   object
#  3   ESTADO                          2609 non-null   object
#  4   UF                              2609 non-null   object
#  5   REGIÃO                          2645 non-null   object
#  6   REGIAO_ORIGEM                   484 non-null    object
#  7   MUDANCA_ESTADO                  2645 non-null   float64
#  8   ENSINO                          2645 non-null   object
#  9   FORMACAO                        2581 non-null   object
#  10  SITUACAO                        2645 non-null   object
#  11  SETOR                           2365 non-null   object
# ...

# %%
import matplotlib.pyplot as plt

# %%
#Histograma
df.FORMACAO.hist();
